# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

os.makedirs(
    "../Outputs/Notebook_15",
    exist_ok=True
)

print(
    "Libraries Loaded Successfully"
)
# Out:
# Libraries Loaded Successfully

# %% [markdown]
# # Authentication Performance Summary

# %%
authentication_df = pd.DataFrame({

    "Metric": [

        "Accuracy",
        "Average Genuine Score",
        "Average Impostor Score"

    ],

    "Value": [

        68.75,
        0.3311143858980883,
        0.013066238090218679

    ]

})

authentication_df
# Out:
#                    Metric      Value
# 0                Accuracy  68.750000
# 1   Average Genuine Score   0.331114
# 2  Average Impostor Score   0.013066

# %% [markdown]
# # Security Evaluation Summary

# %%
security_df = pd.DataFrame({

    "Metric": [

        "Encryption Robustness",
        "Reconstruction Resistance",
        "Privacy Leakage",
        "Matching Reliability"

    ],

    "Result": [

        "High",
        "Strong",
        "Low",
        "Good"

    ]

})

security_df
# Out:
#                       Metric  Result
# 0      Encryption Robustness    High
# 1  Reconstruction Resistance  Strong
# 2            Privacy Leakage     Low
# 3       Matching Reliability    Good

# %% [markdown]
# # Comparative Security Analysis

# %%
comparison_df = pd.DataFrame({

    "Method": [

        "Raw Template Matching",
        "AES-Based Matching",
        "Homomorphic Matching"

    ],

    "Security": [

        "Low",
        "Medium",
        "Very High"

    ],

    "Accuracy": [

        "High",
        "High",
        "68.75%"

    ],

    "Speed": [

        "Fast",
        "Medium",
        "Slower"

    ]

})

comparison_df
# Out:
#                   Method   Security Accuracy   Speed
# 0  Raw Template Matching        Low     High    Fast
# 1     AES-Based Matching     Medium     High  Medium
# 2   Homomorphic Matching  Very High   68.75%  Slower

# %% [markdown]
# # Authentication Accuracy Graph

# %%
plt.figure(
    figsize=(8,5)
)

plt.bar(

    ["Accuracy"],

    [68.75]

)

plt.title(
    "Authentication Accuracy"
)

plt.ylabel(
    "Percentage"
)

plt.savefig(

    "../Outputs/Notebook_15/authentication_accuracy.png"

)

plt.show()

# %% [markdown]
# # Genuine vs Impostor Score Comparison

# %%
score_df = pd.DataFrame({

    "Category": [

        "Genuine",
        "Impostor"

    ],

    "Score": [

       0.32788110274803284,
       0.0035622413664079602

    ]

})

score_df
# Out:
#    Category     Score
# 0   Genuine  0.327881
# 1  Impostor  0.003562

# %% [markdown]
# # Average Matching Score Graph

# %%
plt.figure(
    figsize=(8,5)
)

plt.bar(

    score_df["Category"],

    score_df["Score"]

)

plt.title(
    "Average Matching Scores"
)

plt.ylabel(
    "Similarity Score"
)

plt.savefig(

    "../Outputs/Notebook_15/matching_score_comparison.png"

)

plt.show()

# %% [markdown]
# # Security Evaluation Table

# %%
security_df
# Out:
#                       Metric  Result
# 0      Encryption Robustness    High
# 1  Reconstruction Resistance  Strong
# 2            Privacy Leakage     Low
# 3       Matching Reliability    Good

# %% [markdown]
# # Final Project Summary

# %%
final_summary = pd.DataFrame({

    "Category": [

        "Authentication",
        "Security",
        "Privacy",
        "Encryption"

    ],

    "Result": [

        "Successful",
        "Strong",
        "Preserved",
        "Implemented"

    ]

})

final_summary
# Out:
#          Category       Result
# 0  Authentication   Successful
# 1        Security       Strong
# 2         Privacy    Preserved
# 3      Encryption  Implemented

# %% [markdown]
# # Save Final Results

# %%
final_summary.to_csv(

    "../Outputs/Notebook_15/final_research_summary.csv",

    index=False

)

print(
    "Final Research Evaluation Completed"
)
# Out:
# Final Research Evaluation Completed

# %%
authentication_df.to_csv(

    "../Outputs/Notebook_15/authentication_results.csv",

    index=False

)

comparison_df.to_csv(

    "../Outputs/Notebook_15/comparative_analysis.csv",

    index=False

)

security_df.to_csv(

    "../Outputs/Notebook_15/security_evaluation.csv",

    index=False

)

print(
    "All Results Saved Successfully"
)
# Out:
# All Results Saved Successfully

# %%
plt.figure(figsize=(8,5))

metrics = [
    "Accuracy",
    "Genuine Score",
    "Impostor Score"
]

values = [
    68.75,
    33.11,
    1.31
]

plt.bar(metrics, values)

plt.title(
    "Authentication Performance Summary"
)

plt.ylabel(
    "Percentage / Relative Score"
)

plt.savefig(
    "../Outputs/Notebook_15/authentication_performance_summary.png"
)

plt.show()
